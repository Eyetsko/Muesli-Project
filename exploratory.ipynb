# %%
import pandas as pd

# %%
orders = pd.read_excel('Muesli Project raw data.xlsx', sheet_name=0, header=1)
campaign = pd.read_excel('Muesli Project raw data.xlsx', sheet_name=1, header=0)
process = pd.read_excel('Muesli Project raw data.xlsx', sheet_name=2, header=0)
intern = pd.read_excel('Muesli Project raw data.xlsx', sheet_name=3, header=0)

# %%
orders['Order ID'].nunique()
# Out:
# 5009

# %%
campaign.head(2)
# Out:
#          Order ID Arrival Scan Date Customer Name
# 0  CA-2019-109666        2019-05-03  Kunst Miller
# 1  CA-2019-138933        2019-05-03   Jack Lebron

# %%
all_orders['Order ID'].nunique()
# Out:
# 22

# %%
campaign
# Out:
#            Order ID Arrival Scan Date     Customer Name
# 0    CA-2019-109666        2019-05-03      Kunst Miller
# 1    CA-2019-138933        2019-05-03       Jack Lebron
# 2    CA-2019-130001        2019-05-03  Heather Kirkland
# 3    CA-2019-113061        2019-05-06         Ed Ludwig
# 4    CA-2019-162138        2019-05-06       Grace Kelly
# ..              ...               ...               ...
# 328  CA-2020-129707        2020-05-08      Larry Hughes
# 329  CA-2020-125381        2020-05-08  Speros Goranitis
# 330  CA-2020-141733        2020-05-15       Rick Wilson
# 331  US-2020-104451        2020-05-15    Michelle Moray
# 332  US-2020-139647        2020-05-15      Todd Sumrall
#
# [333 rows x 3 columns]

# %%
all_orders = orders.merge(intern, on='Order ID', how='inner')

# %%
all_orders = all_orders.merge(process,  on='Order ID', how='inner')

# %%
all_orders = all_orders.merge(campaign,  on='Order ID', how='inner')

# %%
all_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Index               250 non-null    int64
#  1   Order ID            250 non-null    object
#  2   Order Date_x        250 non-null    datetime64[ns]
#  3   Ship Mode_x         250 non-null    object
#  4   Customer ID         250 non-null    object
#  5   Customer Name_x     250 non-null    object
#  6   Origin Channel      250 non-null    object
#  7   Country/Region      250 non-null    object
#  8   City                250 non-null    object
#  9   State               250 non-null    object
#  10  Postal Code         250 non-null    float64
#  11  Region              250 non-null    object
#  12  Category            250 non-null    object
#  13  Sub-Category        250 non-null    object
#  14  Product ID          250 non-null    object
# ...

# %%
all_orders.info()

# %%
#how many days from order date is ready date
all_orders['ready_time'] = all_orders['Ready to Ship Date'] - all_orders['Order Date_x'] #time from order to status ready
all_orders['scan_time'] = all_orders['On Truck Scan Date'] - all_orders['Ready to Ship Date'] #time from ready to on truck
all_orders['ship_time'] = all_orders['Arrival Scan Date']- all_orders['On Truck Scan Date'] #time from on truck to arrival
all_orders['order_time'] = all_orders['Arrival Scan Date'] - all_orders['Order Date_x']   #full delivery time

# %%
california = all_orders[all_orders['State'] == 'California']
new_york = all_orders[all_orders['State'] == 'New York']

# %%
new_york.describe()
# Out:
#              Index                   Order Date_x   Postal Code       Sales  \
# count    41.000000                             41     41.000000   41.000000
# mean   4149.463415  2019-09-05 21:04:23.414634240  10014.243902   85.519951
# min     992.000000            2019-09-04 00:00:00  10011.000000    6.690000
# 25%    1620.000000            2019-09-04 00:00:00  10011.000000   22.720000
# 50%    5331.000000            2019-09-04 00:00:00  10011.000000   60.600000
# 75%    5332.000000            2019-09-06 00:00:00  10011.000000   63.940000
# max    8046.000000            2019-09-20 00:00:00  10035.000000  722.352000
# std    1954.020242                            NaN      8.089439  157.276561
#
#         Quantity   Discount      Profit             Ready to Ship Date  \
# count  41.000000  41.000000   41.000000                             41
# mean    2.902439   0.058537   20.827932  2019-09-10 18:43:54.146341376
# ...

# %%
california.describe()
# Out:
#              Index                   Order Date_x   Postal Code        Sales  \
# count   138.000000                            138    138.000000   138.000000
# mean   3455.239130  2019-09-19 00:10:26.086956544  94001.130435   224.417812
# min     251.000000            2019-09-04 00:00:00  92037.000000     7.610000
# 25%    3412.000000            2019-09-20 00:00:00  94122.000000    48.640000
# 50%    3413.000000            2019-09-20 00:00:00  94122.000000    65.790000
# 75%    3414.000000            2019-09-20 00:00:00  94122.000000    77.520000
# max    9930.000000            2019-09-20 00:00:00  94122.000000  3347.370000
# std    1417.118525                            NaN    489.015812   637.747348
#
#          Quantity    Discount      Profit             Ready to Ship Date  \
# count  138.000000  138.000000  138.000000                            138
# mean     3.978261    0.076812   64.199530  2019-09-23 00:10:26.086956544
# ...

# %%
all_orders
# Out:
#      Index        Order ID Order Date_x     Ship Mode_x Customer ID  \
# 0      252  CA-2019-145625   2019-09-11  Standard Class    KC-16540
# 1      252  CA-2019-145625   2019-09-11  Standard Class    KC-16540
# 2      252  CA-2019-145625   2019-09-11  Standard Class    KC-16540
# 3      252  CA-2019-145625   2019-09-11  Standard Class    KC-16540
# 4     1042  CA-2019-102981   2019-09-06    Second Class    MO-17500
# ..     ...             ...          ...             ...         ...
# 245   9929  CA-2019-129630   2019-09-04     First Class    IM-15055
# 246   9069  CA-2019-106278   2019-09-02    Second Class    BM-11140
# 247   9069  CA-2019-106278   2019-09-02    Second Class    BM-11140
# 248   9069  CA-2019-106278   2019-09-02    Second Class    BM-11140
# 249   9069  CA-2019-106278   2019-09-02    Second Class    BM-11140
#
#      Customer Name_x Origin Channel Country/Region           City       State  \
# ...

# %%
express_orders = all_orders[all_orders['Ship Mode_y'] == 'Express']
standard_orders = all_orders[all_orders['Ship Mode_y'] == 'Standard Processing']

# %%
express_orders.describe()
# Out:
#              Index                   Order Date_x   Postal Code        Sales  \
# count    14.000000                             14     14.000000    14.000000
# mean   3900.785714  2019-09-03 15:25:42.857142784  42879.214286   816.883143
# min     870.000000            2019-09-02 00:00:00  10024.000000    14.624000
# 25%     870.250000            2019-09-03 00:00:00  19143.000000   133.399500
# 50%     871.000000            2019-09-03 00:00:00  19143.000000   280.782000
# 75%    9181.000000            2019-09-04 00:00:00  85754.750000  1141.470000
# max    9930.000000            2019-09-09 00:00:00  94122.000000  2799.960000
# std    4265.444971                            NaN  35524.561237   955.673017
#
#         Quantity   Discount      Profit             Ready to Ship Date  \
# count  14.000000  14.000000   14.000000                             14
# mean    3.714286   0.400000  -99.572957  2019-09-05 01:42:51.428571392
# ...

# %%
standard_orders.describe()
# Out:
#              Index                   Order Date_x   Postal Code        Sales  \
# count   236.000000                            236    236.000000   236.000000
# mean   3765.682203  2019-09-14 07:37:37.627118592  68011.652542   163.701843
# min      99.000000            2019-09-02 00:00:00   7050.000000     2.907000
# 25%    3411.000000            2019-09-06 00:00:00  27360.000000    22.720000
# 50%    3413.000000            2019-09-20 00:00:00  94122.000000    63.940000
# 75%    5331.000000            2019-09-20 00:00:00  94122.000000    87.168000
# max    9973.000000            2019-09-27 00:00:00  98198.000000  3347.370000
# std    1836.111682                            NaN  35635.637274   446.525799
#
#          Quantity    Discount      Profit             Ready to Ship Date  \
# count  236.000000  236.000000  236.000000                            236
# mean     3.622881    0.108898   32.868217  2019-09-18 16:16:16.271186432
# ...

# %%
express_orders
# Out:
#      Index        Order ID Order Date_x  Ship Mode_x Customer ID  \
# 99     871  CA-2019-158099   2019-09-03  First Class    PK-18910
# 100    871  CA-2019-158099   2019-09-03  First Class    PK-18910
# 101    871  CA-2019-158099   2019-09-03  First Class    PK-18910
# 102    871  CA-2019-158099   2019-09-03  First Class    PK-18910
# 107   9930  CA-2019-129630   2019-09-04  First Class    IM-15055
# 108   9930  CA-2019-129630   2019-09-04  First Class    IM-15055
# 122    870  CA-2019-158099   2019-09-03  First Class    PK-18910
# 123    870  CA-2019-158099   2019-09-03  First Class    PK-18910
# 124    870  CA-2019-158099   2019-09-03  First Class    PK-18910
# 125    870  CA-2019-158099   2019-09-03  First Class    PK-18910
# 126    992  CA-2019-110023   2019-09-09  First Class    TS-21610
# 243   6937  CA-2019-129847   2019-09-02  First Class    TA-21385
# 244   9929  CA-2019-129630   2019-09-04  First Class    IM-15055
# ...

# %%
scan_time'
